# %%
import pandas as pd

df = pd.read_csv('MSFR_Data_AllTypes - MSFR_Data_Cleaned (1).csv')
df_new = pd.read_csv('full_mfsr_data_complete.csv')

# %%
df.columns
# Out:
# Index(['Sector', 'Project Name', 'Analysis', 'Analysis Information Extracted',
#        'Type', 'Type English', 'URL', 'Date', 'File Size', 'Document_ID',
#        'Project_ID', 'Feasibility Study Type', 'Recommendation',
#        'Description of Recommendation', 'Feasibility_Study_Complete',
#        'EIIR_Estimated', 'EIIR_Above_Viable', 'Climate Change Mentioned',
#        'LLM Model Used', 'Unnamed: 19'],
#       dtype='object')

# %%
df_new.head()
# Out:
#    Sector                                       Project Name  \
# 0  Obrana  Rekonštrukcia leteckej základne Sliač (aktuali...
# 1  Obrana  Rekonštrukcia leteckej základne Sliač (aktuali...
# 2  Obrana  Rekonštrukcia leteckej základne Sliač (aktuali...
# 3  Obrana  Rekonštrukcia leteckej základne Sliač (aktuali...
# 4  Obrana  Obstaranie útočnej pušky 5,56 mm s príslušenstvom
#
#                              Type  \
# 0                hodnotenie (PDF)
# 1  štúdia uskutočniteľnosti (PDF)
# 2                hodnotenie (PDF)
# 3  štúdia uskutočniteľnosti (PDF)
# 4                hodnotenie (PDF)
#
#                                                  URL        Date File Size
# 0  https://www.mfsr.sk/files/archiv/28/mo_sliac_a...   23.1.2025    140 kB
# 1  https://www.mosr.sk/data/files/5761_priloha-7-...         NaN       NaN
# 2  https://www.mfsr.sk/files/archiv/28/MO_Sliac_a...   4.10.2024    165 kB
# 3  https://www.mosr.sk/data/files/5691_semai-195-...         NaN       NaN
# ...
