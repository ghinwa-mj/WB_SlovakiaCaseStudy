# %%
#!/usr/bin/env python3
"""
Complete MFSR scraper that captures ALL documents from all sectors.
Loops through all sector pages and extracts all documents regardless of type.
"""

import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd
import re
import sys
import traceback
import time

BASE = "https://www.mfsr.sk"

# All sector URLs to scrape
SECTOR_URLS = {
    "Obrana": "https://www.mfsr.sk/sk/financie/hodnota-za-peniaze/hodnotenia/obrana.html",
    "Budovy": "https://www.mfsr.sk/sk/financie/hodnota-za-peniaze/hodnotenia/budovy.html", 
    "Doprava": "https://www.mfsr.sk/sk/financie/hodnota-za-peniaze/hodnotenia/doprava.html",
    "Informatizacia": "https://www.mfsr.sk/sk/financie/hodnota-za-peniaze/hodnotenia/informatizacia.html",
    "Ostatne": "https://www.mfsr.sk/sk/financie/hodnota-za-peniaze/hodnotenia/ostatne.html"
}

# Regexes
date_re = re.compile(r'\b\d{1,2}\.\d{1,2}\.\d{4}\b')
size_re = re.compile(r'\b\d+(?:[.,]\d+)?\s*(?:kB|KB|MB|GB|B|kb|mb|gb)\b')

def extract_date_and_size(anchor):
    """Search for date and size strings around the anchor."""
    search_texts = []

    try:
        search_texts.append(anchor.get_text(" ", strip=True))
    except Exception:
        pass

    if anchor.parent:
        try:
            search_texts.append(anchor.parent.get_text(" ", strip=True))
        except Exception:
            pass

    for sib in list(anchor.previous_siblings)[:12]:
        if hasattr(sib, "get_text"):
            search_texts.append(sib.get_text(" ", strip=True))
        else:
            search_texts.append(str(sib).strip())

    for sib in list(anchor.next_siblings)[:6]:
        if hasattr(sib, "get_text"):
            search_texts.append(sib.get_text(" ", strip=True))
        else:
            search_texts.append(str(sib).strip())

    combined = " ".join([t for t in search_texts if t])
    date_match = date_re.search(combined)
    size_match = size_re.search(combined)

    return date_match.group(0) if date_match else None, size_match.group(0) if size_match else None

def is_document_link(href, link_text):
    """Check if link is a document (PDF, Word, Excel, PowerPoint, etc.)."""
    if not href:
        return False
    
    href_l = href.lower()
    link_text_l = link_text.lower()
    
    # Common document extensions
    document_extensions = [
        '.pdf', '.doc', '.docx', '.xls', '.xlsx', '.ppt', '.pptx',
        '.txt', '.rtf', '.odt', '.ods', '.odp', '.csv', '.xml',
        '.zip', '.rar', '.7z', '.tar', '.gz'
    ]
    
    # Check for extensions in href
    for ext in document_extensions:
        if ext in href_l:
            return True
    
    # Check for document keywords in link text
    document_keywords = [
        'pdf', 'document', 'doc', 'excel', 'spreadsheet', 'presentation',
        'powerpoint', 'word', 'text', 'file', 'download', 'attachment'
    ]
    
    for keyword in document_keywords:
        if keyword in link_text_l:
            return True
    
    return False

def determine_document_type(link_text, parent_text=""):
    """Determine document type from link text and parent context."""
    text_to_search = f"{link_text} {parent_text}".lower()
    
    # Standard types
    if 'hodnotenie' in text_to_search:
        return 'hodnotenie'
    elif 'analýza' in text_to_search or 'analyza' in text_to_search:
        return 'analýza'
    elif 'štúdia uskutočniteľnosti' in text_to_search:
        return 'štúdia uskutočniteľnosti'
    elif 'aktualizácia' in text_to_search:
        return 'aktualizácia'
    elif 'stanovisko' in text_to_search:
        return 'stanovisko'
    elif 'správa' in text_to_search:
        return 'správa'
    elif 'metodika' in text_to_search:
        return 'metodika'
    elif 'zmluva' in text_to_search:
        return 'zmluva'
    elif 'dohoda' in text_to_search:
        return 'dohoda'
    elif 'investičný zámer' in text_to_search:
        return 'investičný zámer'
    else:
        # If no specific type found, use the link text itself (truncated)
        return link_text[:50] + "..." if len(link_text) > 50 else link_text

def scrape_sector_page(sector_name, page_url, session):
    """Scrape a single sector page and return list of documents."""
    print(f"\nScraping {sector_name} sector: {page_url}")
    
    try:
        resp = session.get(page_url, timeout=20)
        if resp.status_code != 200:
            print(f"Non-200 status code for {sector_name}: {resp.status_code}")
            return []

        resp.encoding = resp.apparent_encoding or 'utf-8'
        soup = BeautifulSoup(resp.text, "lxml")

        rows = []
        seen = set()
        last_project_name = "UNKNOWN_PROJECT"

        # Loop through all headers and links in order
        for elem in soup.find_all(["h4", "h5", "a"]):
            if elem.name == "h4":
                # Skip h4 headers as we're using sector_name from the URL
                continue
            elif elem.name == "h5":
                last_project_name = elem.get_text(" ", strip=True)
            elif elem.name == "a" and is_document_link(elem.get("href"), elem.get_text(" ", strip=True)):
                link_text = elem.get_text(" ", strip=True)

                # Determine type - captures ALL document types
                parent_text = elem.parent.get_text(" ", strip=True) if elem.parent else ""
                dtype = determine_document_type(link_text, parent_text)

                url = urljoin(BASE, elem["href"])
                date, size = extract_date_and_size(elem)

                # Use URL as unique key to avoid duplicates
                key = (sector_name, last_project_name, url)
                if key not in seen:
                    rows.append((sector_name, last_project_name, dtype, url, date or "", size or ""))
                    seen.add(key)

        print(f"Found {len(rows)} documents in {sector_name}")
        return rows

    except Exception as e:
        print(f"Error scraping {sector_name}: {e}")
        return []

def main():
    """Main function to scrape all sectors."""
    try:
        session = requests.Session()
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                          "AppleWebKit/537.36 (KHTML, like Gecko) "
                          "Chrome/117.0.0.0 Safari/537.36",
            "Accept-Language": "en-US,en;q=0.9,sk;q=0.8"
        }
        session.headers.update(headers)

        all_rows = []
        
        # Scrape each sector
        for sector_name, page_url in SECTOR_URLS.items():
            sector_rows = scrape_sector_page(sector_name, page_url, session)
            all_rows.extend(sector_rows)
            
            # Small delay between requests to be respectful
            time.sleep(1)

        # Create DataFrame
        df = pd.DataFrame(all_rows, columns=["Sector", "Project Name", "Type", "URL", "Date", "File Size"])
        
        print(f"\n{'='*60}")
        print(f"SCRAPING COMPLETE")
        print(f"{'='*60}")
        print(f"Total documents collected: {len(df)}")
        
        # Show summary by sector
        print(f"\nDocuments by sector:")
        sector_counts = df['Sector'].value_counts()
        for sector, count in sector_counts.items():
            print(f"  {sector}: {count}")
        
        # Show unique document types found
        print(f"\nUnique document types found:")
        unique_types = df['Type'].value_counts()
        for doc_type, count in unique_types.items():
            print(f"  {doc_type}: {count}")
        
        # Show sample of results
        print(f"\nSample of results:")
        print(df.head(10).to_string(index=False))
        
        # Save to CSV
        output_file = "full_mfsr_data_complete.csv"
        df.to_csv(output_file, index=False, encoding="utf-8-sig")
        print(f"\nSaved complete data to: {output_file}")
        
        # Show some examples of the previously missed document types
        print(f"\nExamples of 'Aktualizácia' documents:")
        aktualizacia_docs = df[df['Type'] == 'aktualizácia']
        if not aktualizacia_docs.empty:
            print(aktualizacia_docs[['Sector', 'Project Name', 'Type', 'Date']].head().to_string(index=False))
        
        print(f"\nExamples of 'Stanovisko' documents:")
        stanovisko_docs = df[df['Type'] == 'stanovisko']
        if not stanovisko_docs.empty:
            print(stanovisko_docs[['Sector', 'Project Name', 'Type', 'Date']].head().to_string(index=False))

    except Exception as e:
        print("Exception occurred:", e)
        traceback.print_exc()
        sys.exit(1)

if __name__ == "__main__":
    main()
# Out:
# /Users/ghinwamoujaes/Desktop/World Bank/Code/slovakia_CaseStudy/wb_venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Scraping Obrana sector: https://www.mfsr.sk/sk/financie/hodnota-za-peniaze/hodnotenia/obrana.html
# Found 28 documents in Obrana
#
# Scraping Budovy sector: https://www.mfsr.sk/sk/financie/hodnota-za-peniaze/hodnotenia/budovy.html
# Found 44 documents in Budovy
#
# Scraping Doprava sector: https://www.mfsr.sk/sk/financie/hodnota-za-peniaze/hodnotenia/doprava.html
# Found 148 documents in Doprava
#
# Scraping Informatizacia sector: https://www.mfsr.sk/sk/financie/hodnota-za-peniaze/hodnotenia/informatizacia.html
# Found 112 documents in Informatizacia
#
# Scraping Ostatne sector: https://www.mfsr.sk/sk/financie/hodnota-za-peniaze/hodnotenia/ostatne.html
# Found 22 documents in Ostatne
#
# ============================================================
# SCRAPING COMPLETE
# ============================================================
# Total documents collected: 354
#
# Documents by sector:
#   Doprava: 148
#   Informatizacia: 112
#   Budovy: 44
#   Obrana: 28
#   Ostatne: 22
#
# Unique document types found:
#   analýza: 206
#   hodnotenie: 63
#   štúdia uskutočniteľnosti: 52
#   stanovisko: 9
#   Dohody o hraničných priechodoch: 5
#   Aktualizovaná štúdia: 3
#   aktualizácia: 2
#   Grafy a tabuľky: 2
#   Dodatočné poklady od Národnej diaľničnej spoločnos...: 1
#   Doplnenie štúdie uskutočniteľnosti: 1
#   Doplnenie hodnotenia: 1
#   Korekcia diaľničných známok: 1
#   Odhad nákladov na dokončenie D1 - Lietavská Lúčka ...: 1
#   Otázky a odpovede: 1
#   Aktualizovaná časť štúdie uskutočniteľnosti: 1
#   Dátová príloha: Úpravy v CBA pre obchvat Veľkého L...: 1
#   Najčastejšie otázky a odpovede: 1
#   Štúdia implementácie IT: 1
#   Aktualizovaná štúdia od investora: 1
#   Prognóza: 1
#
# Sample of results:
# Sector                                                                      Project Name                            Type                                                                                                                                               URL       Date File Size
# Obrana                                                                   UNKNOWN_PROJECT Dohody o hraničných priechodoch                     https://www.mfsr.sk/sk/dane-cla-uctovnictvo/colna-oblast/cla/dohovory-dohody-diagonalne-dohody/dohody-hranicnych-priechodoch/
# Obrana         Rekonštrukcia leteckej základne Sliač (aktualizácia pred podpisom zmluvy)                      hodnotenie                                                                     https://www.mfsr.sk/files/archiv/28/mo_sliac_aktualizacia_zmluva_20250123.pdf  23.1.2025    140 kB
# Obrana         Rekonštrukcia leteckej základne Sliač (aktualizácia pred podpisom zmluvy)        štúdia uskutočniteľnosti https://www.mosr.sk/data/files/5761_priloha-7-formular-na-aktualizaciu-studie-uskutocnitelnosti-pred-vytvorenim-zavazku-podpisom-zmluvy-final.pdf
# Obrana                              Rekonštrukcia leteckej základne Sliač (aktualizácia)                      hodnotenie                                                                            https://www.mfsr.sk/files/archiv/28/MO_Sliac_aktualizacia_20241004.pdf  4.10.2024    165 kB
# Obrana                              Rekonštrukcia leteckej základne Sliač (aktualizácia)        štúdia uskutočniteľnosti                                                                                         https://www.mosr.sk/data/files/5691_semai-195-20-2024.pdf
# Obrana                                 Obstaranie útočnej pušky 5,56 mm s príslušenstvom                      hodnotenie                                                                               https://www.mfsr.sk/files/archiv/48/UHP_Hodnotenie_Utocne-pusky.pdf 18.10.2023    405 kB
# Obrana                                 Obstaranie útočnej pušky 5,56 mm s príslušenstvom        štúdia uskutočniteľnosti                                   https://www.mosr.sk/data/files/5222_tudia-uskutocnitelnosti-obstarania-556mm-utocnej-pusky-s-prislusenstvom.pdf
# Obrana Akvizícia palebných prostriedkov protivzdušnej obrany – prvá etapa (aktualizácia)                         analýza                                                                                    https://www.mfsr.sk/files/archiv/6/UHP_MO_Aktualizacia_PVO.pdf  19.9.2023    692 kB
# Obrana Akvizícia palebných prostriedkov protivzdušnej obrany – prvá etapa (aktualizácia)        štúdia uskutočniteľnosti                            https://www.mosr.sk/data/files/5202_formular-na-aktualizaciu-studie-uskutocnitelnosti-obstarania-pp-pvo-prva-etapa.pdf
# Obrana                                    Obstarávanie stavby na leteckej základni Sliač                         analýza                                                                                   https://www.mfsr.sk/files/archiv/51/LZ-Sliac_hodnotenie_UHP.pdf   9.6.2023    361 kB
#
# Saved complete data to: full_mfsr_data_complete.csv
#
# Examples of 'Aktualizácia' documents:
#         Sector                                                                         Project Name         Type      Date
#         Obrana               Obmena rádiolokačnej techniky VzS OS SR (stredný, malý a blízky dosah) aktualizácia 25.3.2021
# Informatizacia Vývoj a konštrukcia superpočítača pre národné superpočítačové centrum (aktualizácia) aktualizácia
#
# Examples of 'Stanovisko' documents:
#  Sector                                                                   Project Name       Type       Date
#  Obrana                           Hodnotenie nákupu viacúčelových taktických lietadiel stanovisko
#  Budovy Úrad vlády SR - Rekonštrukcia kaštieľa v Rusovciach (Aktualizované hodnotenie) stanovisko
#  Budovy                            Úrad vlády SR - Rekonštrukcia kaštieľa v Rusovciach stanovisko
# Doprava                                               Implementácia TSI TAF/TAP na ŽSR stanovisko 14.12.2018
# Doprava                                              Nákup diagnostických vozidiel ŽSR stanovisko

# %%
df = pd.read_csv('full_mfsr_data_complete.csv')

# %%
len(df)
# Out:
# 354

# %%
len(df['Project Name'].unique())
# Out:
# 266

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import random

def create_unique_ids(df):
    """
    Create unique IDs for documents based on sector and chronological order.
    
    Step 1: Create an ID for each Sector
    Step 2: For each sector, create an ID that increases with the date order 
            and then increases randomly for the non-date documents
    Step 3: The Final ID will be SectorID.2ndID
    
    Args:
        df: DataFrame with columns ['Sector', 'Project Name', 'Type', 'URL', 'Date', 'File Size']
    
    Returns:
        DataFrame with additional 'Document_ID' column
    """
    
    # Step 1: Define sector mapping (SectorID)
    sector_mapping = {
        'Doprava': 1,
        'Informatizacia': 2, 
        'Budovy': 3,
        'Obrana': 4,
        'Ostatne': 5
    }
    
    # Convert Date column to datetime, handling NaN values
    def parse_date(date_str):
        if pd.isna(date_str) or date_str == '':
            return None
        try:
            # Handle Slovak date format DD.MM.YYYY
            return datetime.strptime(str(date_str), '%d.%m.%Y')
        except:
            return None
    
    df['Date_parsed'] = df['Date'].apply(parse_date)
    
    # Create a copy to work with
    df_with_ids = df.copy()
    df_with_ids['Document_ID'] = ''
    
    # Process each sector separately
    for sector, sector_id in sector_mapping.items():
        print(f"Processing sector: {sector} (SectorID: {sector_id})")
        
        # Filter dataframe to only this sector
        sector_df = df_with_ids[df_with_ids['Sector'] == sector].copy()
        
        if len(sector_df) == 0:
            print(f"  No documents found for {sector}")
            continue
            
        print(f"  Found {len(sector_df)} documents for {sector}")
        
        # Step 2: Sort by date (documents with dates first, then without dates)
        sector_df = sector_df.sort_values('Date_parsed', na_position='last')
        
        # Assign sequential IDs starting from 01 for documents with dates
        date_documents = sector_df[sector_df['Date_parsed'].notna()]
        no_date_documents = sector_df[sector_df['Date_parsed'].isna()]
        
        # Assign sequential IDs to documents with dates
        for i, (idx, row) in enumerate(date_documents.iterrows(), 1):
            # Use 3-digit formatting from the start to avoid float conversion issues
            doc_id = f"{sector_id}.{i:03d}"
            df_with_ids.loc[idx, 'Document_ID'] = doc_id
            print(f"    Assigned {doc_id} to document with date at index {idx}")
        
        # Assign random sequential IDs to documents without dates
        if len(no_date_documents) > 0:
            # Get the highest ID number used for this sector
            max_id = len(date_documents)
            
            # Create random order for no-date documents
            no_date_indices = no_date_documents.index.tolist()
            random.shuffle(no_date_indices)
            
            for i, idx in enumerate(no_date_indices):
                doc_num = max_id + i + 1
                # Use 3-digit formatting from the start
                doc_id = f"{sector_id}.{doc_num:03d}"
                df_with_ids.loc[idx, 'Document_ID'] = doc_id
                print(f"    Assigned {doc_id} to document without date at index {idx}")
    
    # Ensure Document_ID column is stored as string and force string type
    df_with_ids['Document_ID'] = df_with_ids['Document_ID'].astype(str)
    
    return df_with_ids.drop('Date_parsed', axis=1)

def main():
    # Load the data
    df = pd.read_csv('full_mfsr_data_complete.csv')
    
    print("="*60)
    print("CREATING UNIQUE DOCUMENT IDs")
    print("="*60)
    print(f"Total documents: {len(df)}")
    print(f"Sectors: {df['Sector'].value_counts().to_dict()}")
    print()
    
    # Create unique IDs
    df_with_ids = create_unique_ids(df)
    
    print("\n" + "="*60)
    print("RESULTS")
    print("="*60)
    
    # Save the result
    df_with_ids.to_csv("full_mfsr_data_completewith_ids.csv", index=False, encoding="utf-8-sig")
    print("Saved results to: full_mfsr_data_with_ids.csv")
    
    # Show summary by sector
    print("\nID ranges by sector:")
    for sector in ['Doprava', 'Informatizacia', 'Budovy', 'Obrana', 'Ostatne']:
        sector_data = df_with_ids[df_with_ids['Sector'] == sector]['Document_ID']
        if not sector_data.empty:
            print(f"{sector}: {sector_data.min()} to {sector_data.max()} ({len(sector_data)} documents)")
    
    # Show sample results
    print("\nSample of results:")
    sample_cols = ['Document_ID', 'Sector', 'Project Name', 'Date']
    print(df_with_ids[sample_cols].head(10).to_string(index=False))
    
    # Verify all documents have IDs
    missing_ids = len(df_with_ids[df_with_ids['Document_ID'] == ''])
    print(f"\nDocuments without IDs: {missing_ids}")
    print(f"Total documents processed: {len(df_with_ids)}")
    
    # Show examples by sector
    print("\nFirst 3 IDs for each sector:")
    for sector in ['Doprava', 'Informatizacia', 'Budovy', 'Obrana', 'Ostatne']:
        sector_data = df_with_ids[df_with_ids['Sector'] == sector]['Document_ID'].head(3)
        if not sector_data.empty:
            print(f"{sector}: {sector_data.tolist()}")

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# CREATING UNIQUE DOCUMENT IDs
# ============================================================
# Total documents: 354
# Sectors: {'Doprava': 148, 'Informatizacia': 112, 'Budovy': 44, 'Obrana': 28, 'Ostatne': 22}
#
# Processing sector: Doprava (SectorID: 1)
#   Found 148 documents for Doprava
#     Assigned 1.001 to document with date at index 219
#     Assigned 1.002 to document with date at index 216
#     Assigned 1.003 to document with date at index 218
#     Assigned 1.004 to document with date at index 217
#     Assigned 1.005 to document with date at index 215
#     Assigned 1.006 to document with date at index 214
#     Assigned 1.007 to document with date at index 213
#     Assigned 1.008 to document with date at index 211
#     Assigned 1.009 to document with date at index 210
#     Assigned 1.010 to document with date at index 209
#     Assigned 1.011 to document with date at index 208
#     Assigned 1.012 to document with date at index 207
#     Assigned 1.013 to document with date at index 206
#     Assigned 1.014 to document with date at index 205
#     Assigned 1.015 to document with date at index 202
#     Assigned 1.016 to document with date at index 198
#     Assigned 1.017 to document with date at index 204
#     Assigned 1.018 to document with date at index 201
#     Assigned 1.019 to document with date at index 200
#     Assigned 1.020 to document with date at index 203
#     Assigned 1.021 to document with date at index 197
#     Assigned 1.022 to document with date at index 195
#     Assigned 1.023 to document with date at index 194
#     Assigned 1.024 to document with date at index 193
#     Assigned 1.025 to document with date at index 192
#     Assigned 1.026 to document with date at index 191
#     Assigned 1.027 to document with date at index 190
#     Assigned 1.028 to document with date at index 187
#     Assigned 1.029 to document with date at index 189
#     Assigned 1.030 to document with date at index 188
#     Assigned 1.031 to document with date at index 186
#     Assigned 1.032 to document with date at index 185
#     Assigned 1.033 to document with date at index 183
#     Assigned 1.034 to document with date at index 182
#     Assigned 1.035 to document with date at index 181
#     Assigned 1.036 to document with date at index 180
#     Assigned 1.037 to document with date at index 179
#     Assigned 1.038 to document with date at index 177
#     Assigned 1.039 to document with date at index 176
#     Assigned 1.040 to document with date at index 174
#     Assigned 1.041 to document with date at index 172
#     Assigned 1.042 to document with date at index 171
#     Assigned 1.043 to document with date at index 169
#     Assigned 1.044 to document with date at index 167
#     Assigned 1.045 to document with date at index 165
#     Assigned 1.046 to document with date at index 163
#     Assigned 1.047 to document with date at index 162
#     Assigned 1.048 to document with date at index 161
#     Assigned 1.049 to document with date at index 160
#     Assigned 1.050 to document with date at index 159
#     Assigned 1.051 to document with date at index 158
#     Assigned 1.052 to document with date at index 157
#     Assigned 1.053 to document with date at index 156
#     Assigned 1.054 to document with date at index 155
#     Assigned 1.055 to document with date at index 153
#     Assigned 1.056 to document with date at index 152
#     Assigned 1.057 to document with date at index 151
#     Assigned 1.058 to document with date at index 150
#     Assigned 1.059 to document with date at index 148
#     Assigned 1.060 to document with date at index 145
#     Assigned 1.061 to document with date at index 147
#     Assigned 1.062 to document with date at index 146
#     Assigned 1.063 to document with date at index 143
#     Assigned 1.064 to document with date at index 142
#     Assigned 1.065 to document with date at index 141
#     Assigned 1.066 to document with date at index 140
#     Assigned 1.067 to document with date at index 139
#     Assigned 1.068 to document with date at index 138
#     Assigned 1.069 to document with date at index 136
#     Assigned 1.070 to document with date at index 135
#     Assigned 1.071 to document with date at index 134
#     Assigned 1.072 to document with date at index 133
#     Assigned 1.073 to document with date at index 132
#     Assigned 1.074 to document with date at index 131
#     Assigned 1.075 to document with date at index 130
#     Assigned 1.076 to document with date at index 128
#     Assigned 1.077 to document with date at index 127
#     Assigned 1.078 to document with date at index 126
#     Assigned 1.079 to document with date at index 125
#     Assigned 1.080 to document with date at index 124
#     Assigned 1.081 to document with date at index 123
#     Assigned 1.082 to document with date at index 121
#     Assigned 1.083 to document with date at index 120
#     Assigned 1.084 to document with date at index 119
#     Assigned 1.085 to document with date at index 117
#     Assigned 1.086 to document with date at index 116
#     Assigned 1.087 to document with date at index 115
#     Assigned 1.088 to document with date at index 114
#     Assigned 1.089 to document with date at index 113
#     Assigned 1.090 to document with date at index 112
#     Assigned 1.091 to document with date at index 109
#     Assigned 1.092 to document with date at index 108
#     Assigned 1.093 to document with date at index 107
#     Assigned 1.094 to document with date at index 106
#     Assigned 1.095 to document with date at index 105
#     Assigned 1.096 to document with date at index 104
#     Assigned 1.097 to document with date at index 103
#     Assigned 1.098 to document with date at index 102
#     Assigned 1.099 to document with date at index 101
#     Assigned 1.100 to document with date at index 98
#     Assigned 1.101 to document with date at index 97
#     Assigned 1.102 to document with date at index 95
#     Assigned 1.103 to document with date at index 93
#     Assigned 1.104 to document with date at index 91
#     Assigned 1.105 to document with date at index 90
#     Assigned 1.106 to document with date at index 88
#     Assigned 1.107 to document with date at index 87
#     Assigned 1.108 to document with date at index 85
#     Assigned 1.109 to document with date at index 83
#     Assigned 1.110 to document with date at index 81
#     Assigned 1.111 to document with date at index 79
#     Assigned 1.112 to document with date at index 77
#     Assigned 1.113 to document with date at index 75
#     Assigned 1.114 to document with date at index 74
#     Assigned 1.115 to document with date at index 73
#     Assigned 1.116 to document without date at index 118
#     Assigned 1.117 to document without date at index 111
#     Assigned 1.118 to document without date at index 110
#     Assigned 1.119 to document without date at index 92
#     Assigned 1.120 to document without date at index 96
#     Assigned 1.121 to document without date at index 78
#     Assigned 1.122 to document without date at index 184
#     Assigned 1.123 to document without date at index 82
#     Assigned 1.124 to document without date at index 129
#     Assigned 1.125 to document without date at index 122
#     Assigned 1.126 to document without date at index 199
#     Assigned 1.127 to document without date at index 175
#     Assigned 1.128 to document without date at index 72
#     Assigned 1.129 to document without date at index 144
#     Assigned 1.130 to document without date at index 166
#     Assigned 1.131 to document without date at index 86
#     Assigned 1.132 to document without date at index 80
#     Assigned 1.133 to document without date at index 149
#     Assigned 1.134 to document without date at index 212
#     Assigned 1.135 to document without date at index 196
#     Assigned 1.136 to document without date at index 170
#     Assigned 1.137 to document without date at index 94
#     Assigned 1.138 to document without date at index 173
#     Assigned 1.139 to document without date at index 84
#     Assigned 1.140 to document without date at index 164
#     Assigned 1.141 to document without date at index 89
#     Assigned 1.142 to document without date at index 137
#     Assigned 1.143 to document without date at index 168
#     Assigned 1.144 to document without date at index 178
#     Assigned 1.145 to document without date at index 76
#     Assigned 1.146 to document without date at index 154
#     Assigned 1.147 to document without date at index 100
#     Assigned 1.148 to document without date at index 99
# Processing sector: Informatizacia (SectorID: 2)
#   Found 112 documents for Informatizacia
#     Assigned 2.001 to document with date at index 331
#     Assigned 2.002 to document with date at index 330
#     Assigned 2.003 to document with date at index 328
#     Assigned 2.004 to document with date at index 329
#     Assigned 2.005 to document with date at index 327
#     Assigned 2.006 to document with date at index 326
#     Assigned 2.007 to document with date at index 325
#     Assigned 2.008 to document with date at index 324
#     Assigned 2.009 to document with date at index 323
#     Assigned 2.010 to document with date at index 322
#     Assigned 2.011 to document with date at index 321
#     Assigned 2.012 to document with date at index 319
#     Assigned 2.013 to document with date at index 316
#     Assigned 2.014 to document with date at index 318
#     Assigned 2.015 to document with date at index 317
#     Assigned 2.016 to document with date at index 315
#     Assigned 2.017 to document with date at index 314
#     Assigned 2.018 to document with date at index 313
#     Assigned 2.019 to document with date at index 312
#     Assigned 2.020 to document with date at index 311
#     Assigned 2.021 to document with date at index 310
#     Assigned 2.022 to document with date at index 309
#     Assigned 2.023 to document with date at index 308
#     Assigned 2.024 to document with date at index 307
#     Assigned 2.025 to document with date at index 306
#     Assigned 2.026 to document with date at index 303
#     Assigned 2.027 to document with date at index 305
#     Assigned 2.028 to document with date at index 304
#     Assigned 2.029 to document with date at index 302
#     Assigned 2.030 to document with date at index 301
#     Assigned 2.031 to document with date at index 300
#     Assigned 2.032 to document with date at index 299
#     Assigned 2.033 to document with date at index 298
#     Assigned 2.034 to document with date at index 297
#     Assigned 2.035 to document with date at index 296
#     Assigned 2.036 to document with date at index 295
#     Assigned 2.037 to document with date at index 294
#     Assigned 2.038 to document with date at index 293
#     Assigned 2.039 to document with date at index 292
#     Assigned 2.040 to document with date at index 291
#     Assigned 2.041 to document with date at index 290
#     Assigned 2.042 to document with date at index 289
#     Assigned 2.043 to document with date at index 287
#     Assigned 2.044 to document with date at index 286
#     Assigned 2.045 to document with date at index 285
#     Assigned 2.046 to document with date at index 284
#     Assigned 2.047 to document with date at index 283
#     Assigned 2.048 to document with date at index 282
#     Assigned 2.049 to document with date at index 281
#     Assigned 2.050 to document with date at index 280
#     Assigned 2.051 to document with date at index 279
#     Assigned 2.052 to document with date at index 278
#     Assigned 2.053 to document with date at index 277
#     Assigned 2.054 to document with date at index 276
#     Assigned 2.055 to document with date at index 275
#     Assigned 2.056 to document with date at index 274
#     Assigned 2.057 to document with date at index 273
#     Assigned 2.058 to document with date at index 272
#     Assigned 2.059 to document with date at index 271
#     Assigned 2.060 to document with date at index 270
#     Assigned 2.061 to document with date at index 269
#     Assigned 2.062 to document with date at index 268
#     Assigned 2.063 to document with date at index 267
#     Assigned 2.064 to document with date at index 266
#     Assigned 2.065 to document with date at index 265
#     Assigned 2.066 to document with date at index 264
#     Assigned 2.067 to document with date at index 263
#     Assigned 2.068 to document with date at index 262
#     Assigned 2.069 to document with date at index 261
#     Assigned 2.070 to document with date at index 260
#     Assigned 2.071 to document with date at index 258
#     Assigned 2.072 to document with date at index 257
#     Assigned 2.073 to document with date at index 256
#     Assigned 2.074 to document with date at index 254
#     Assigned 2.075 to document with date at index 253
#     Assigned 2.076 to document with date at index 252
#     Assigned 2.077 to document with date at index 251
#     Assigned 2.078 to document with date at index 250
#     Assigned 2.079 to document with date at index 249
#     Assigned 2.080 to document with date at index 248
#     Assigned 2.081 to document with date at index 247
#     Assigned 2.082 to document with date at index 246
#     Assigned 2.083 to document with date at index 245
#     Assigned 2.084 to document with date at index 244
#     Assigned 2.085 to document with date at index 243
#     Assigned 2.086 to document with date at index 242
#     Assigned 2.087 to document with date at index 240
#     Assigned 2.088 to document with date at index 238
#     Assigned 2.089 to document with date at index 237
#     Assigned 2.090 to document with date at index 236
#     Assigned 2.091 to document with date at index 235
#     Assigned 2.092 to document with date at index 234
#     Assigned 2.093 to document with date at index 232
#     Assigned 2.094 to document with date at index 231
#     Assigned 2.095 to document with date at index 230
#     Assigned 2.096 to document with date at index 233
#     Assigned 2.097 to document with date at index 229
#     Assigned 2.098 to document with date at index 228
#     Assigned 2.099 to document with date at index 227
#     Assigned 2.100 to document with date at index 226
#     Assigned 2.101 to document with date at index 225
#     Assigned 2.102 to document with date at index 224
#     Assigned 2.103 to document with date at index 223
#     Assigned 2.104 to document with date at index 221
#     Assigned 2.105 to document without date at index 255
#     Assigned 2.106 to document without date at index 320
#     Assigned 2.107 to document without date at index 220
#     Assigned 2.108 to document without date at index 288
#     Assigned 2.109 to document without date at index 222
#     Assigned 2.110 to document without date at index 241
#     Assigned 2.111 to document without date at index 239
#     Assigned 2.112 to document without date at index 259
# Processing sector: Budovy (SectorID: 3)
#   Found 44 documents for Budovy
#     Assigned 3.001 to document with date at index 71
#     Assigned 3.002 to document with date at index 70
#     Assigned 3.003 to document with date at index 68
#     Assigned 3.004 to document with date at index 67
#     Assigned 3.005 to document with date at index 65
#     Assigned 3.006 to document with date at index 64
#     Assigned 3.007 to document with date at index 63
#     Assigned 3.008 to document with date at index 62
#     Assigned 3.009 to document with date at index 60
#     Assigned 3.010 to document with date at index 58
#     Assigned 3.011 to document with date at index 57
#     Assigned 3.012 to document with date at index 56
#     Assigned 3.013 to document with date at index 55
#     Assigned 3.014 to document with date at index 54
#     Assigned 3.015 to document with date at index 52
#     Assigned 3.016 to document with date at index 51
#     Assigned 3.017 to document with date at index 50
#     Assigned 3.018 to document with date at index 49
#     Assigned 3.019 to document with date at index 48
#     Assigned 3.020 to document with date at index 47
#     Assigned 3.021 to document with date at index 45
#     Assigned 3.022 to document with date at index 44
#     Assigned 3.023 to document with date at index 43
#     Assigned 3.024 to document with date at index 42
#     Assigned 3.025 to document with date at index 41
#     Assigned 3.026 to document with date at index 40
#     Assigned 3.027 to document with date at index 38
#     Assigned 3.028 to document with date at index 37
#     Assigned 3.029 to document with date at index 36
#     Assigned 3.030 to document with date at index 35
#     Assigned 3.031 to document with date at index 33
#     Assigned 3.032 to document with date at index 32
#     Assigned 3.033 to document with date at index 30
#     Assigned 3.034 to document with date at index 29
#     Assigned 3.035 to document without date at index 28
#     Assigned 3.036 to document without date at index 59
#     Assigned 3.037 to document without date at index 39
#     Assigned 3.038 to document without date at index 66
#     Assigned 3.039 to document without date at index 53
#     Assigned 3.040 to document without date at index 61
#     Assigned 3.041 to document without date at index 34
#     Assigned 3.042 to document without date at index 31
#     Assigned 3.043 to document without date at index 69
#     Assigned 3.044 to document without date at index 46
# Processing sector: Obrana (SectorID: 4)
#   Found 28 documents for Obrana
#     Assigned 4.001 to document with date at index 27
#     Assigned 4.002 to document with date at index 25
#     Assigned 4.003 to document with date at index 24
#     Assigned 4.004 to document with date at index 22
#     Assigned 4.005 to document with date at index 20
#     Assigned 4.006 to document with date at index 21
#     Assigned 4.007 to document with date at index 18
#     Assigned 4.008 to document with date at index 16
#     Assigned 4.009 to document with date at index 14
#     Assigned 4.010 to document with date at index 13
#     Assigned 4.011 to document with date at index 11
#     Assigned 4.012 to document with date at index 9
#     Assigned 4.013 to document with date at index 7
#     Assigned 4.014 to document with date at index 5
#     Assigned 4.015 to document with date at index 3
#     Assigned 4.016 to document with date at index 1
#     Assigned 4.017 to document without date at index 19
#     Assigned 4.018 to document without date at index 12
#     Assigned 4.019 to document without date at index 6
#     Assigned 4.020 to document without date at index 4
#     Assigned 4.021 to document without date at index 15
#     Assigned 4.022 to document without date at index 2
#     Assigned 4.023 to document without date at index 23
#     Assigned 4.024 to document without date at index 10
#     Assigned 4.025 to document without date at index 0
#     Assigned 4.026 to document without date at index 26
#     Assigned 4.027 to document without date at index 17
#     Assigned 4.028 to document without date at index 8
# Processing sector: Ostatne (SectorID: 5)
#   Found 22 documents for Ostatne
#     Assigned 5.001 to document with date at index 351
#     Assigned 5.002 to document with date at index 352
#     Assigned 5.003 to document with date at index 353
#     Assigned 5.004 to document with date at index 350
#     Assigned 5.005 to document with date at index 349
#     Assigned 5.006 to document with date at index 348
#     Assigned 5.007 to document with date at index 346
#     Assigned 5.008 to document with date at index 345
#     Assigned 5.009 to document with date at index 343
#     Assigned 5.010 to document with date at index 342
#     Assigned 5.011 to document with date at index 340
#     Assigned 5.012 to document with date at index 338
#     Assigned 5.013 to document with date at index 337
#     Assigned 5.014 to document with date at index 335
#     Assigned 5.015 to document with date at index 333
#     Assigned 5.016 to document without date at index 347
#     Assigned 5.017 to document without date at index 341
#     Assigned 5.018 to document without date at index 336
#     Assigned 5.019 to document without date at index 332
#     Assigned 5.020 to document without date at index 344
#     Assigned 5.021 to document without date at index 334
#     Assigned 5.022 to document without date at index 339
#
# ============================================================
# RESULTS
# ============================================================
# Saved results to: full_mfsr_data_with_ids.csv
#
# ID ranges by sector:
# Doprava: 1.001 to 1.148 (148 documents)
# Informatizacia: 2.001 to 2.112 (112 documents)
# Budovy: 3.001 to 3.044 (44 documents)
# Obrana: 4.001 to 4.028 (28 documents)
# Ostatne: 5.001 to 5.022 (22 documents)
#
# Sample of results:
# Document_ID Sector                                                                      Project Name       Date
#       4.025 Obrana                                                                   UNKNOWN_PROJECT        NaN
#       4.016 Obrana         Rekonštrukcia leteckej základne Sliač (aktualizácia pred podpisom zmluvy)  23.1.2025
#       4.022 Obrana         Rekonštrukcia leteckej základne Sliač (aktualizácia pred podpisom zmluvy)        NaN
#       4.015 Obrana                              Rekonštrukcia leteckej základne Sliač (aktualizácia)  4.10.2024
#       4.020 Obrana                              Rekonštrukcia leteckej základne Sliač (aktualizácia)        NaN
#       4.014 Obrana                                 Obstaranie útočnej pušky 5,56 mm s príslušenstvom 18.10.2023
#       4.019 Obrana                                 Obstaranie útočnej pušky 5,56 mm s príslušenstvom        NaN
#       4.013 Obrana Akvizícia palebných prostriedkov protivzdušnej obrany – prvá etapa (aktualizácia)  19.9.2023
#       4.028 Obrana Akvizícia palebných prostriedkov protivzdušnej obrany – prvá etapa (aktualizácia)        NaN
#       4.012 Obrana                                    Obstarávanie stavby na leteckej základni Sliač   9.6.2023
#
# Documents without IDs: 0
# Total documents processed: 354
#
# First 3 IDs for each sector:
# Doprava: ['1.128', '1.115', '1.114']
# Informatizacia: ['2.107', '2.104', '2.109']
# Budovy: ['3.035', '3.034', '3.033']
# Obrana: ['4.025', '4.016', '4.022']
# Ostatne: ['5.019', '5.015', '5.021']
